# %% [markdown]
# ![pic1](pic1.png)

# %% [markdown]
# ![pic2](pic2.png)

# %% [markdown]
# # Product entity yield type prediction # 產品實體產量類型預測
#
# ## Domain 領域
# ### Semiconductor manufacturing process 半導體製造工藝
# ## Business Context 業務背景
# #### A complex modern semiconductor manufacturing process is normally under constant
# 複雜的現代半導體製造製程通常處於恆定的條件下
# #### surveillance via the monitoring of signals/variables collected from sensors and or
# 透過監控從感測器收集的訊號/變數進行監控和/或
# #### process measurement points. However, not all of these signals are equally valuable in
# 過程測量點。然而，並非所有這些訊號都具有同等價值
# #### a specific monitoring system. 特定的監控系統。
# #### The measured signals contain a combination of useful information, irrelevant
# 測量的訊號包含有用資訊、不相關資訊的組合
# #### information as well as noise. Engineers typically have a much larger number of signals
# 資訊和噪音一樣。工程師通常擁有大量訊號
# #### than are actually required. If we consider each type of signal as a feature, then feature
# 比實際需要的多。如果我們將每種類型的訊號視為一個特徵，那麼特徵
# #### selection may be applied to identify the most relevant signals. The Process Engineers
# 可以應用選擇來識別最相關的訊號。製程工程師
# #### may then use these signals to determine key factors contributing to yield excursions
# 然後可以使用這些訊號來確定導致良率偏差的關鍵因素
# #### downstream in the process. This will enable an increase in process throughput,
# 過程中的下游。這將提高流程吞吐量，
# #### decreased time to learning and reduce the per unit production costs.
# 減少學習時間並降低單位生產成本。
# #### These signals can be used as features to predict the yield type. And by analyzing and
# 這些訊號可用作預測產量類型的特徵。並透過分析和
# #### trying out different combinations of features, essential signals that are impacting the
# 嘗試不同的功能組合，影響的基本訊號
# #### yield type can be identified. 可以識別產量類型。
#
# ## Objective 客觀的
# #### We will build a classifier to predict the Pass/Fail yield of a particular process entity and
# 我們將建立一個分類器來預測特定流程實體的通過/失敗率，並
# #### analyze whether all the features are required to build the model or not.
# 分析建構模型是否需要所有特徵。
# Error 500 (Server Error)!!1500.That’s an error.There was an error. Please try again later.That’s all we know.
# 錯誤 500（伺服器錯誤）！ ！ 1500。這是一個錯誤。出現錯誤。請稍後重試。我們只知道這些。
#
# ## Dataset description 資料集描述
#
# #### sensor-data.csv : (1567, 592)
# #### The data consists of 1567 examples each with 591 features. 此資料由 1567 個範例組成，每個範例有 591 個特徵。
# #### 此資料由 1567 個範例組成，每個範例有 591 個特徵。
# #### The dataset presented in this case represents a selection of such features where each
# 本例中提供的資料集代表了此類特徵的選擇，其中每個特徵
# #### example represents a single production entity with associated measured
# 範例表示具有相關測量值的單一生產實體
# #### features and the labels represent a simple pass/fail yield for in house line
# 功能和標籤代表內部生產線的簡單通過/失敗率
# #### testing. Target column “ –1” corresponds to a pass and “1” corresponds to a fail and
# 測試。目標列“-1”對應於通過，“1”對應於失敗，
# #### the data time stamp is for that specific test point. 資料時間戳適用於該特定測試點。
#
# ## Steps 步驟
# 1. Import the necessary liberraries and read the provided CSV as a dataframe and
# 導入必要的庫並讀取提供的 CSV 作為資料框，
# 1. 匯入必要的庫並讀取提供的 CSV 作為資料框並
# perform the below steps.  執行以下步驟。
# a. Check a few observations and shape of the dataframe
# a. 檢查資料框的一些觀察結果和形狀
# b. Check for missing values. Impute the missing values if there is any
# b.檢查是否有缺失值。如果有缺失值，則估算缺失值
# c. Univariate analysis - check frequency count of target column and
# c. 單變量分析 - 檢查目標列的頻率計數和 distribution of the first few features (sensors) 前幾個特徵（感測器）的分佈
# d. Perform bivariate analysis and check for the correlation d.執行雙變量分析並檢查相關性
# e. Drop irrelevant columns e.刪除不相關的列
# 3. Standardize the data 數據標準化
# 4. Segregate the dependent column ("Pass/Fail") from the data frame. And split
# 從資料框中分離相關列（“通過/失敗”）。並分裂
# the dataset into training and testing set ( 70:30 split)  將資料集分為訓練集和測試集（70:30 分割）
# 5. Build a logistic regression, random forest, and xgboost classifier model and print
# 建立邏輯迴歸、隨機森林和 xgboost 分類器模型並列印
# 4. 建立邏輯迴歸、隨機森林和 xgboost 分類器模型並列印
# confusion matrix for the test data  測試數據的混淆矩陣
# 5. Apply sampling techniques to handle the imbalanced classes  應用抽樣技術來處理不平衡的類別
# 5.應用抽樣技術來處理不平衡的類別
# 6. Build a logistic regression, random forest, and xgboost classifier model after resampling the data and print the confusion matrix for the test data
# 對資料進行重採樣後建立邏輯迴歸、隨機森林和 xgboost 分類器模型並列印測試資料的混淆矩陣
# 6.資料重採樣後建構邏輯迴歸、隨機森林和xgboost分類器模型，並列印測試資料的混淆矩陣
# 7. Apply Grid Search CV to get the best hyper parameters for any one of the above
# 應用網格搜尋 CV 以獲得上述任一參數的最佳超參數
# 7. 應用 Grid Search CV 以獲得上述任一參數的最佳超參數
# model  模型
# 8. Build a classifier model using the above best hyper parameters and check the
# 使用上述最佳超參數建立分類器模型並檢查
# Error 500 (Server Error)!!1500.That’s an error.There was an error. Please try again later.That’s all we know.
# 錯誤 500（伺服器錯誤）！ ！ 1500。這是一個錯誤。出現錯誤。請稍後重試。我們只知道這些。
# accuracy and confusion matrix  準確性和混淆矩陣
# 9. Report feature importance and mention your comments  9. 報告功能重要性並提及您的意見
#
# 10. Report your findings and inferences  10. 報告你的發現和推論
# Further Questions ( Optional) - 進一步問題（可選）-
# 1. Check for outliers and impute them as required. 1. 檢查異常值並根據需要進行估算。
# 2. Apply PCA to get rid of redundant features and reduce dimension of the data
# 應用PCA去除冗餘特徵並降低資料維度
# 2.應用PCA去除冗餘特徵並降低資料維度
# 3. Try cross validation techniques to get better results 3.嘗試交叉驗證技術以獲得更好的結果
# 4. Try OneCLassSVM model to get better recall 4.嘗試OneCLassSVM模型以獲得更好的召回率
#
# ### Learning Outcomes 學習成果
# * Feature Importance * 特徵重要性
# * Sampling * 抽樣
# * SMOTE * 輕擊
# * Grid Search * 網格搜尋
# * Random Forest * 隨機森林
# * Exploratory Data Analysis * 探索性資料分析
# * Logistic Regression * 邏輯迴歸

# %% [markdown]
# ## Import Some Basic Libraries 導入一些基礎函式庫

# %%
# for basic operations 用於基本操作
import numpy as np 
import pandas as pd 

# for visualizations 用於可視化
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# for modeling  用於建模
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Lasso
from sklearn.svm import OneClassSVM

# to avoid warnings 以避免警告
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# for providing path 用於提供路徑
import os
print(os.listdir("."))
# Out:
# ['.ipynb_checkpoints', 'fmst-semiconductor-manufacturing.ipynb', 'pic1.png', 'pic2.png', 'requirements.txt', 'uci-secom.csv']

# %% [markdown]
# ## Reading the Data and understanding the attributes 讀取資料並理解屬性

# %%
# reading the data from local workspace file 從本機工作區檔案讀取數據
data = pd.read_csv('uci-secom.csv')

# getting the shape of the data 取得資料的形狀
# we have 1,567 rows and 592 columns 我們有 1,567 行和 592 列
print(data.shape)
# Out:
# (1567, 592)

# %%
# getting the head of the data 取得數據頭

data.head()
# Out:
#                   Time        0        1          2          3       4      5  \
# 0  2008-07-19 11:55:00  3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0
# 1  2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0
# 2  2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0
# 3  2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0
# 4  2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0
#
#           6       7       8  ...       581     582     583     584      585  \
# 0   97.6133  0.1242  1.5005  ...       NaN  0.5005  0.0118  0.0035   2.3630
# 1  102.3433  0.1247  1.4966  ...  208.2045  0.5019  0.0223  0.0055   4.4447
# 2   95.4878  0.1241  1.4436  ...   82.8602  0.4958  0.0157  0.0039   3.1745
# 3  104.2367  0.1217  1.4882  ...   73.8432  0.4990  0.0103  0.0025   2.0544
# 4  100.3967  0.1235  1.5031  ...       NaN  0.4800  0.4766  0.1045  99.3032
#
# ...

# %%
# checking if the dataset contains any NULL values 檢查資料集是否包含任何 NULL 值
# we do have NaN values if we see the output above 如果我們看到上面的輸出，我們確實有 NaN 值

data.isnull().any().any()
# Out:
# np.True_

# %%
# Replacing all the NaN values with 0 as the values correspond to the test results.
# 將所有 NaN 值替換為 0，因為這些值與測試結果相對應。
# 將所有NaN值替換為0 ，因為該值對應於測試結果。
# 將所有 NaN 值替換為 0，因為這些值與測試結果相對應。
# since, the values are not present that means the values are not available or calculated
# 因為，這些值不存在，這意味著這些值不可用或無法計算
# Absence of a signal is assumed to be no signal in the dataset
# 沒有訊號被假定為資料集中沒有訊號
# so better we not take median or mean and replace them with zeros
# 所以最好我們不要取中位數或平均值並將它們替換為零

data = data.replace(np.nan, 0)

# again, checking if there is any NULL values left 再次檢查是否還有 NULL 值
data.isnull().any().any()
# Out:
# np.False_

# %% [markdown]
# ## Data Visualization 資料視覺化

# %%
unique_vals = data['Pass/Fail'].unique()  # [0, 1, 2]
targets = [data.loc[data['Pass/Fail'] == val] for val in unique_vals]

# %%
fig = plt.figure(figsize=(20,20))

plt.subplot(2, 2, 1)
for target in targets:
    sns.histplot(target['1'], kde=False, stat='density')
    sns.rugplot(target['1'])
plt.title('First Sensor Measurements', fontsize = 20)

plt.subplot(2, 2, 2)
for target in targets:
    sns.histplot(target['2'], kde=False, stat='density')
    sns.rugplot(target['2'])
plt.title('Second Sensor Measurements', fontsize = 20)

plt.subplot(2, 2, 3)
for target in targets:
    sns.histplot(target['3'], kde=False, stat='density')
    sns.rugplot(target['3'])
plt.title('Third Sensor Measurements', fontsize = 20)

plt.subplot(2, 2, 4)
for target in targets:
    sns.histplot(target['4'], kde=False, stat='density')
    sns.rugplot(target['4'])
plt.title('Fourth Sensor Measurements', fontsize = 20)

#sns.add_legend() sns.add_legend() sns.add_legend () sns.add_legend ()
# sns.add_legend () sns.add_legend () sns.add_legend () sns.add_legend ()
# sns.add_legend() sns.add_legend() sns.add_legend() sns.add_legend()
# sns.add_legend () sns.add_legend () sns.add_legend () sns.add_legend ()
# sns.add_legend() sns.add_legend() sns.add_legend() sns.add_legend()
# sns.add_legend () sns.add_legend () sns.add_legend () sns.add_legend ()
#plt.legend() plt.圖例()
fig.legend(labels=['Pass','Fail'])
plt.show()

# %%
# pie chart 圓餅圖
# We have highly imbalanced class with only 6.6% failures and 93.4% pass
# 我們的班級高度不平衡，只有 6.6% 的失敗率和 93.4% 的通過率

labels = ['Pass', 'Fail']
size = data['Pass/Fail'].value_counts()
colors = ['blue', 'green']
explode = [0, 0.1]

plt.style.use('seaborn-v0_8-deep')
plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels =labels, colors = colors, explode = explode, autopct = "%.2f%%", shadow = True)
plt.axis('off')
plt.title('Target: Pass or Fail', fontsize = 20)
plt.legend()
plt.show()
data['Pass/Fail'].value_counts().plot(kind="bar");

# %%
# heatmap to get correlation 熱圖以獲得相關性

plt.rcParams['figure.figsize'] = (18, 18)
numeric_data = data.select_dtypes(include='number')
sns.heatmap(numeric_data.corr(), cmap = "YlGnBu")
plt.title('Correlation heatmap for the Data', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Correlation heatmap for the Data')

# %% [markdown]
# ## Data Cleaning/Preprocessing 資料清理/預處理

# %%
#Remove the highly collinear features from data 從資料中去除高度共線性的特徵
def remove_collinear_features(x, threshold):
    '''
    Objective:
        Remove collinear features in a dataframe with a correlation coefficient
        greater than the threshold. Removing collinear features can help a model 
        to generalize and improves the interpretability of the model.

    Inputs: 
        x: features dataframe
        threshold: features with correlations greater than this value are removed

    Output: 
        dataframe that contains only the non-highly-collinear features
    '''

    # Calculate the correlation matrix 計算相關矩陣
    corr_matrix = x.select_dtypes(include='number').corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # Iterate through the correlation matrix and compare correlations
    # 迭代相關矩陣並比較相關性
    for i in iters:
        for j in range(i+1):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)

            # If correlation exceeds the threshold 如果相關性超過閾值
            if val >= threshold:
                # Print the correlated features and the correlation value 列印相關特徵和相關值
                print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                drop_cols.append(col.values[0])

    # Drop one of each pair of correlated columns 刪除每對相關列中的一個
    drops = set(drop_cols)
    x = x.drop(columns=drops)

    return x

# %%
#Remove columns having more than 70% correlation 刪除相關性超過 70% 的列
#Both positive and negative correlations are considered here 這裡同時考慮正相關和負相關
data = remove_collinear_features(data,0.70)
# Out:
# 5 | 2 | 0.99
# 6 | 2 | 0.82
# 6 | 5 | 0.84
# 7 | 2 | 0.75
# 7 | 5 | 0.77
# 12 | 11 | 0.83
# 17 | 11 | 0.81
# 18 | 11 | 0.72
# 18 | 12 | 0.79
# 18 | 17 | 0.9
# 22 | 21 | 0.75
# 26 | 25 | 0.83
# 27 | 25 | 0.98
# 27 | 26 | 0.79
# 30 | 29 | 0.86
# 34 | 32 | 0.88
# 35 | 34 | 0.83
# 37 | 32 | 0.75
# 37 | 34 | 0.75
# 38 | 32 | 0.72
# 38 | 34 | 0.72
# 38 | 36 | 0.71
# 38 | 37 | 0.97
# 39 | 32 | 0.81
# 39 | 34 | 0.91
# 39 | 35 | 0.71
# 39 | 37 | 0.86
# 39 | 38 | 0.84
# 43 | 42 | 0.82
# 44 | 42 | 0.82
# 46 | 42 | 0.84
# 46 | 43 | 0.84
# 46 | 45 | 0.74
# 48 | 44 | 0.77
# 49 | 42 | 1.0
# 49 | 43 | 0.82
# 49 | 44 | 0.82
# 49 | 46 | 0.84
# 50 | 42 | 0.88
# 50 | 43 | 0.9
# 50 | 46 | 0.97
# 50 | 49 | 0.88
# 51 | 47 | 0.71
# 54 | 53 | 1.0
# 55 | 53 | 0.95
# 55 | 54 | 0.95
# 56 | 53 | 0.98
# 56 | 54 | 0.97
# 56 | 55 | 0.96
# 57 | 53 | 0.97
# 57 | 54 | 0.96
# 57 | 55 | 0.98
# 57 | 56 | 0.99
# 58 | 53 | 0.93
# 58 | 54 | 0.93
# 58 | 55 | 0.92
# 58 | 56 | 0.96
# 58 | 57 | 0.94
# 61 | 60 | 0.88
# ...

# %%
# deleting the first column 刪除第一列

data = data.drop(columns = ['Time'], axis = 1)

# checking the shape of the data after deleting a column 刪除列後檢查資料的形狀
data.shape
# Out:
# (1567, 307)

# %%
data.head()
# Out:
#          0        1          2          3       4       8       9      10  \
# 0  3030.93  2564.00  2187.7333  1411.1265  1.3602  1.5005  0.0162 -0.0034
# 1  3095.78  2465.14  2230.4222  1463.6606  0.8294  1.4966 -0.0005 -0.0148
# 2  2932.61  2559.94  2186.4111  1698.0172  1.5102  1.4436  0.0041  0.0013
# 3  2988.72  2479.90  2199.0333   909.7926  1.3204  1.4882 -0.0124 -0.0033
# 4  3032.24  2502.87  2233.3667  1326.5200  1.5334  1.5031 -0.0031 -0.0072
#
#        11   13  ...       570     571    572     578     582     583     586  \
# 0  0.9455  0.0  ...  533.8500  2.1113   8.95  0.0000  0.5005  0.0118  0.0000
# 1  0.9627  0.0  ...  535.0164  2.4335   5.92  0.0096  0.5019  0.0223  0.0096
# 2  0.9615  0.0  ...  535.0245  2.0293  11.21  0.0584  0.4958  0.0157  0.0584
# 3  0.9629  0.0  ...  530.5682  2.0253   9.33  0.0202  0.4990  0.0103  0.0202
# 4  0.9569  0.0  ...  532.0155  2.0275   8.83  0.0000  0.4800  0.4766  0.0202
#
#       587       589  Pass/Fail
# ...

# %%
# separating the dependent and independent data 分離相關數據和獨立數據

x = data.iloc[:,:306]
y = data["Pass/Fail"]

# getting the shapes of new data sets x and y Error 500 (Server Error)!!1500.That’s an error.There was an error. Please try again later.That’s all we know.
# 取得新資料集 x 和 y 的形狀錯誤 500（伺服器錯誤）！ ！ 1500。這是一個錯誤。出現錯誤。請稍後重試。我們只知道這些。
# 獲取新資料集的形狀x和y錯誤500 （伺服器錯誤） ！ ！ 1500。這是一個錯誤。有一個錯誤。請稍後再試。這是我們所知道的。
print("shape of x:", x.shape)
print("shape of y:", y.shape)
# Out:
# shape of x: (1567, 306)
# shape of y: (1567,)

# %%
# splitting them into train test and split 將它們分為訓練測試和拆分

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# gettiing the shapes 取得形狀
print("shape of x_train: ", x_train.shape)
print("shape of x_test: ", x_test.shape)
print("shape of y_train: ", y_train.shape)
print("shape of y_test: ", y_test.shape)
# Out:
# shape of x_train:  (1096, 306)
# shape of x_test:  (471, 306)
# shape of y_train:  (1096,)
# shape of y_test:  (471,)

# %%
# standardization 標準化

from sklearn.preprocessing import StandardScaler

# creating a standard scaler 建立標準縮放器
sc = StandardScaler()

# fitting independent data to the model 將獨立數據擬合到模型中
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ## XGBoost Algorithm (Normal data); XGBoost演算法（普通資料）

# %%
model = XGBClassifier(random_state=1)
model.fit(x_train, (np.ravel(y_train) == 1).astype(int))
y_pred = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
sns.heatmap(cm, annot = True, annot_kws = {"size": 15})
# Out:
# <Axes: >

# %%
print("Accuracy: ", model.score(x_test,y_test)*100)
# Out:
# Accuracy:  0.0

# %% [markdown]
# #### In the failure class we have only 1 observation classified correctly for XGBoost but still has 94.5% accuracy as we predicted correctly on the observations that passed
# 在失敗類別中，我們只有 1 個觀測值被正確分類為 XGBoost，但仍具有 94.5% 的準確度，因為我們對通過的觀測值進行了正確預測
# #### 在失敗類別中，我們只有 1 個觀測值被正確分類為 XGBoost，但仍具有 94.5% 的準確度，因為我們對通過的觀測值進行了正確預測

# %% [markdown]
# ## Random Forest Classifier (Normal Data); 隨機森林分類器（普通資料）

# %%
model = RandomForestClassifier(n_estimators=100, random_state=1,verbose=0 )
model.fit(x_train, np.ravel(y_train))
y_pred = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
sns.heatmap(cm, annot = True, annot_kws = {"size": 15})
# Out:
# <Axes: >

# %%
print("Accuracy: ", model.score(x_test,y_test)*100)
# Out:
# Accuracy:  93.20594479830149

# %% [markdown]
# #### In the failure class we have no observation classified correctly for Random Forest but still has 94.5% accuracy as we predicted correctly on the observations that passed
# 在失敗類別中，我們沒有對隨機森林正確分類的觀察結果，但仍然具有 94.5% 的準確度，因為我們對通過的觀察結果進行了正確預測

# %% [markdown]
# ## Logistic Regression (Normal Data); 邏輯迴歸（常態資料）

# %%
lr = LogisticRegression(random_state=1)
lr.fit(x_train, np.ravel(y_train)) 
y_pred = lr.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
sns.heatmap(cm, annot = True, annot_kws = {"size": 15})
# Out:
# <Axes: >

# %%
print("Accuracy: ", lr.score(x_test,y_test)*100)
# Out:
# Accuracy:  90.65817409766454

# %% [markdown]
# #### In the failure class we have 4 observation classified correctly for logistic regression and 88% accuracy as we predicted correctly on the observations that passed. So even though this model has lesser accuracy it is preferable over previous models as at least it is classifying more observations in the failure class correctly
# 在失敗類別中，我們有 4 個觀察值被正確分類為邏輯迴歸，並且我們對通過的觀察值進行了正確預測，準確率為 88%。因此，儘管該模型的準確性較低，但它比以前的模型更可取，因為至少它可以正確地對故障類別中的更多觀察結果進行分類

# %% [markdown]
# ## Lasso (Normal Data); 套索（普通資料）

# %%
lasso = Lasso(alpha=0.1,random_state=1)
lasso.fit(x_train, np.ravel(y_train))
#print ("Lasso model:", (lasso.coef_)) print ("套索模型：", (lasso.coef_))

y_pred = lasso.predict(x_test)

#Convert the sign of the predicted values as the classifier 將預測值的符號轉換為分類器
y_pred2 = np.sign(y_pred)

# %%
print("Accuracy: ", lasso.score(x_test,y_test)*100)
# Out:
# Accuracy:  -0.007974076019068299

# %%
cm = confusion_matrix(y_test, y_pred2)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %% [markdown]
# ## UnderSampling of the Dataset; 資料集欠取樣

# %%
# Under Sampling - Check how many failure observations are there
# 採樣下 - 檢查有多少個故障觀察結果
# We have 104 such observations 我們有 104 個這樣的觀察結果

failed_tests = np.array(data[data['Pass/Fail'] == 1].index)
no_failed_tests = len(failed_tests)

print(no_failed_tests)
# Out:
# 104

# %%
# Check how many pass observations are there 檢查有多少次通過觀察
# We have 1,463 such observations 我們有 1,463 個這樣的觀察結果

normal_indices = data[data['Pass/Fail'] == -1]
no_normal_indices = len(normal_indices)

print(no_normal_indices)
# Out:
# 1463

# %%
# Get 104 random observations from the pass class as well 也從合格類別中獲得 104 個隨機觀察結果

random_normal_indices = np.random.choice(no_normal_indices, size = no_failed_tests, replace = True)
random_normal_indices = np.array(random_normal_indices)

print(len(random_normal_indices))
# Out:
# 104

# %%
#Getting a 50-50 representation from both pass and fail classes
# 透過類和失敗類均獲得 50-50 的表現
under_sample = np.concatenate([failed_tests, random_normal_indices])
print(len(under_sample))
# Out:
# 208

# %%
# creating the undersample data 創建欠採樣數據

undersample_data = data.iloc[under_sample, :]

# %%
# splitting the undersample dataset into x and y sets 將欠採樣資料集拆分為 x 和 y 集

x = undersample_data.iloc[:, undersample_data.columns != 'Pass/Fail'] 
y = undersample_data.iloc[:, undersample_data.columns == 'Pass/Fail']

print(x.shape)
print(y.shape)
# Out:
# (208, 306)
# (208, 1)

# %%
from sklearn.model_selection import train_test_split

x_train_us, x_test_us, y_train_us, y_test_us = train_test_split(x, y, test_size = 0.3, random_state = 1)

print(x_train_us.shape)
print(y_train_us.shape)
print(x_test_us.shape)
print(y_test_us.shape)
# Out:
# (145, 306)
# (145, 1)
# (63, 306)
# (63, 1)

# %%
# standardization 標準化

sc = StandardScaler()
x_train_us = sc.fit_transform(x_train_us)
x_test_us = sc.transform(x_test_us)

# %% [markdown]
# ## Xg-Boost Classifier (Undersampling); Xg-Boost 分類器（欠採樣）

# %%
model = XGBClassifier(random_state=1)

model.fit(x_train_us, (np.ravel(y_train_us) == 1).astype(int))

y_pred = model.predict(x_test_us)

# %% [markdown]
# ## Confusion Matrix after UnderSampling with XgBoost; 使用 XgBoost 進行欠取樣後的混淆矩陣

# %%
cm = confusion_matrix(y_test_us, y_pred)

plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
sns.heatmap(cm, annot = True, annot_kws = {"size": 15})

# It is able to predict 26 defected semiconductors among 35 Semi-Conductors
# 能夠預測 35 種半導體中的 26 種缺陷半導體
# Out:
# <Axes: >

# %%
print("Accuracy: ", model.score(x_test,y_test)*100)
# Out:
# Accuracy:  6.1571125265392785

# %% [markdown]
# ## Grid Search - XG Boost (Undersampling); 網格搜尋 - XG Boost（欠採樣）

# %%
# Applying Grid Search CV to find the best model with the best parameters
# 應用 Grid Search CV 尋找具有最佳參數的最佳模型
# 應用網格搜尋CV以尋找具有最佳參數的最佳模型
# 應用 Grid Search CV 尋找具有最佳參數的最佳模型

parameters = [{'max_depth' : [1, 2, 3, 4, 5, 6],
              'random_state' : [1]}]

grid_search = GridSearchCV(estimator = model, param_grid = parameters, scoring = 'accuracy', cv = 5, n_jobs = -1)

grid_search = grid_search.fit(x_train_us, (np.ravel(y_train_us) == 1).astype(int))
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_

# %%
print("Best Accuracy: ", best_accuracy*100)
print("Best Parameter: ", best_parameters)
# Out:
# Best Accuracy:  67.58620689655173
# Best Parameter:  {'max_depth': 2, 'random_state': 1}

# %%
y_train_us_xgb = (np.ravel(y_train_us) == 1).astype(int)
weights = float((y_train_us_xgb == 0).sum()) / max(1.0, float((y_train_us_xgb == 1).sum()))
model = XGBClassifier(max_depth = 1, scale_pos_weight = weights, n_jobs = 4, random_state=1)

model.fit(x_train_us, (np.ravel(y_train_us) == 1).astype(int))

y_pred = model.predict(x_test_us)

# %%
print("Accuracy: ", model.score(x_test,y_test)*100)
# Out:
# Accuracy:  6.369426751592357

# %% [markdown]
# ## Confusion matrix XG Boost - Grid Search (Undersample); 混淆矩陣 XG Boost - 網格搜尋（欠採樣）

# %%
cm = confusion_matrix(y_test_us, y_pred)

plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
sns.heatmap(cm, annot = True, annot_kws = {"size": 15})
# Out:
# <Axes: >

# %% [markdown]
# **Most Important Features of the Model** **該模型最重要的特徵**

# %%
# plotting the feature importances 繪製特徵重要性

colors = plt.cm.spring(np.linspace(0, 1, 9))
xgb.plot_importance(model, height = 1, color = colors, grid = True, importance_type = 'cover', show_values = False)

plt.rcParams['figure.figsize'] = (100, 100)
plt.xlabel('The F-Score for each features')
plt.ylabel('Importances')
plt.show()

# %% [markdown]
# ## Over-Sampling with SMOTE; 使用 SMOTE 進行過採樣

# %%
x_resample, y_resample  = SMOTE(random_state=1).fit_resample(x, y.values.ravel())

print(x_resample.shape)
print(y_resample.shape)
# Out:
# (224, 306)
# (224,)

# %%
x_train_os, x_test_os, y_train_os, y_test_os = train_test_split(x, y, test_size = 0.3, random_state = 1)

print(x_train_os.shape)
print(y_train_os.shape)
print(x_test_os.shape)
print(y_test_os.shape)
# Out:
# (145, 306)
# (145, 1)
# (63, 306)
# (63, 1)

# %%
# standardization 標準化

sc = StandardScaler()
x_train_os = sc.fit_transform(x_train_os)
x_test_os = sc.transform(x_test_os)

# %% [markdown]
# ## Xg-Boost Classifier - Grid Search (Oversampling); Xg-Boost 分類器 - 網格搜尋（過採樣）

# %%
import xgboost as xgb
from xgboost.sklearn import XGBClassifier

model = XGBClassifier(random_state=1)

model.fit(x_train_os, (np.ravel(y_train_os) == 1).astype(int))

y_pred = model.predict(x_test_os)

# %%
# Applying Grid Search CV to find the best model with the best parameters
# 應用 Grid Search CV 尋找具有最佳參數的最佳模型
# 應用網格搜尋CV以尋找具有最佳參數的最佳模型
# 應用 Grid Search CV 尋找具有最佳參數的最佳模型

from sklearn.model_selection import GridSearchCV

# making a parameters list 製作參數列表
parameters = [{'max_depth' : [1, 2, 3, 4, 5, 6],
              'random_state' : [1]}]

# making a grid search model 製作網格搜尋模型
grid_search = GridSearchCV(estimator = model, param_grid = parameters, scoring = 'accuracy', cv = 5, n_jobs = -1)
grid_search = grid_search.fit(x_train_os, (np.ravel(y_train_os) == 1).astype(int))

# getting the results 得到結果
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_

# %%
print("Best Accuracy: ", best_accuracy)
print("Best Parameter: ", best_parameters)
# Out:
# Best Accuracy:  0.6758620689655173
# Best Parameter:  {'max_depth': 2, 'random_state': 1}

# %%
y_train_os_xgb = (np.ravel(y_train_os) == 1).astype(int)
weights = float((y_train_os_xgb == 0).sum()) / max(1.0, float((y_train_os_xgb == 1).sum()))
model = XGBClassifier(max_depth = 1, scale_pos_weight = weights, n_jobs = 4, random_state=1)

model.fit(x_train_os, (np.ravel(y_train_os) == 1).astype(int))

y_pred = model.predict(x_test_os)

# %% [markdown]
# ## Confusion Matrix after OverSampling with XgBoost; 使用 XgBoost 過採樣後的混淆矩陣

# %%
cm = confusion_matrix(y_test_os, y_pred)

plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
sns.heatmap(cm, annot = True, annot_kws = {"size": 15}, cmap = 'spring')
# Out:
# <Axes: >

# %%
print("Accuracy: ", model.score(x_test,y_test)*100)
# Out:
# Accuracy:  6.369426751592357

# %% [markdown]
# ## Random Forest (Oversampling); 隨機森林（過採樣）

# %%
model = RandomForestClassifier(n_estimators=100, random_state=1,verbose=0 )
model.fit(x_train_os, np.ravel(y_train_os))
#scores_prediction = model.decision_function(x_train) Scores_prediction = model.decision_function(x_train)
# 分數_預測 = model.decision_function(x_train) 分數_預測 = model.decision_function(x_train)
# scores_prediction = model.decision_function (x_train) Scores_prediction = model.decision_function (x_train)
# 分數_預測 = model.decision_function (x_train) 分數_預測 = model.decision_function (x_train)
y_pred = model.predict(x_test_os)
print("Accuracy: ", model.score(x_test_os,y_test_os)*100)
# Out:
# Accuracy:  65.07936507936508
# Accuracy:  66.66666666666666
# Accuracy:  74.60317460317461

# %% [markdown]
# ## Random Forest - (Oversampled) - Confusion Matrix; 隨機森林 - （過採樣） - 混淆矩陣

# %%
# printing the confusion matrix 列印混淆矩陣
cm = confusion_matrix(y_test_os, y_pred)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %% [markdown]
# ## Logistic regression - (Oversampled); 邏輯迴歸 - （過採樣）

# %%
lr = LogisticRegression(random_state=1)
lr.fit(x_train_os, np.ravel(y_train_os)) 
y_pred = lr.predict(x_test_os)

print("Accuracy: ", lr.score(x_test_os,y_test_os)*100)
# Out:
# Accuracy:  57.14285714285714
# F:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# F:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## Logistic regression (Oversampled) - Confusion matrix; 邏輯迴歸（過取樣）- 混淆矩陣

# %%
cm = confusion_matrix(y_test_os, y_pred)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %% [markdown]
# ## Random Forest - (Undersampled); 隨機森林 -（欠採樣）

# %%
model = RandomForestClassifier(n_estimators=100, random_state=1,verbose=0 )
model.fit(x_train_us, np.ravel(y_train_us))
#scores_prediction = model.decision_function(x_train) Scores_prediction = model.decision_function(x_train)
# 分數_預測 = model.decision_function(x_train) 分數_預測 = model.decision_function(x_train)
# scores_prediction = model.decision_function (x_train) Scores_prediction = model.decision_function (x_train)
# 分數_預測 = model.decision_function (x_train) 分數_預測 = model.decision_function (x_train)
y_pred = model.predict(x_test_us)

# %% [markdown]
# ## Confusion Matrix for Random Forest (Undersampled); 隨機森林的混淆矩陣（欠採樣）

# %%
# evaluating the model 評估模型

# printing the confusion matrix 列印混淆矩陣
cm = confusion_matrix(y_test_us, y_pred)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %%
print("Accuracy: ", model.score(x_test,y_test)*100)
# Out:
# Accuracy:  61.3588110403397

# %% [markdown]
# ## Using Lasso (Undersampled); 使用套索（欠採樣）

# %%
lasso = Lasso(alpha=0.1,random_state=1)
lasso.fit(x_train_us, np.ravel(y_train_us))
#print ("Lasso model:", (lasso.coef_)) print ("套索模型：", (lasso.coef_))
# Out:
# Lasso(alpha=0.1, random_state=1)

# %%
y_pred = lasso.predict(x_test_us)

# %%
print(y_pred)
# Out:
# [-0.11330211  0.65334012 -0.095418   -0.65339826  0.02260962  0.40180186
#   0.92828337  0.5679052  -0.12100287 -0.20998011  0.92828337  0.13076101
#  -0.10590539  0.19407496  0.5423523  -0.6030759   0.21671291  1.74981339
#   0.46040535  0.19969378  1.86807751 -0.20699394  0.37178924  0.58849851
#  -0.15646983  0.18794481  0.44789931  0.31747082  0.42096678 -0.17873008
#   0.40317554 -0.62778924  0.6289971   0.51085233 -0.45896976 -0.23075436
#   0.44264371  0.29068699  0.09003014  0.47145846  0.12332388  0.5011403
#   0.48020172  0.14601762  0.05969315  0.17013212 -0.0134589  -0.18171112
#   0.18794481 -0.12619982 -0.10590539 -0.0901608  -0.22111411  0.43620171
#   0.07769289 -0.55457527  0.61741717 -0.43972763 -0.47682293  0.08722397
#   0.0744303   0.27012826 -0.07812806]

# %%
print(y_test_us)
# Out:
#       Pass/Fail
# 1451         -1
# 27           -1
# 970          -1
# 938          -1
# 495           1
# ...         ...
# 1302          1
# 273           1
# 755          -1
# 324          -1
# 441           1
#
# [63 rows x 1 columns]

# %%
#Convert the sign of the predicted values as the classifier 將預測值的符號轉換為分類器
y_pred2 = np.sign(y_pred)

# %% [markdown]
# ## Confusion matrix for Lasso (Undersampled); Lasso 的混淆矩陣（欠取樣）

# %%
cm = confusion_matrix(y_test_us, y_pred2)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %%
print("Accuracy: ", lasso.score(x_test_us,y_test_us)*100)
# Out:
# Accuracy:  -13.569435112332219

# %% [markdown]
# ## Logistic Regression (Undersampled); 邏輯迴歸（欠取樣）

# %%
lr = LogisticRegression(random_state=1)
lr.fit(x_train_us, np.ravel(y_train_us))
# Out:
# LogisticRegression(random_state=1)

# %%
y_pred = lr.predict(x_test_us)

# %% [markdown]
# ## Confusion matrix for Logistic Regression (Undersampled); Logistic 迴歸的混淆矩陣（欠取樣）

# %%
cm = confusion_matrix(y_test_us, y_pred)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %%
print("Accuracy: ", lr.score(x_test,y_test)*100)
# Out:
# Accuracy:  54.989384288747345

# %% [markdown]
# > **Local Outlier Factor Classifier,** Succesfully detected 11 defected items out of 13, that makes an impeccable accuracy of 85% Recall Accuracy. This algorithm would have been worked even better if the data was a little bigger with more instances of defected items.
# 局部離群因子分類器，** 成功檢測到 13 個缺陷項目中的 11 個，這使得召回準確度達到 85% 的無可挑剔的準確度。如果資料稍微大一些，缺陷商品的實例更多，那麼該演算法的效果會更好。

# %% [markdown]
# ## One Class SVM (Undersampled); 一類 SVM（欠取樣）

# %% [markdown]
# > In one-class SVM, the support vector model is trained on data that has only one class, which is the “normal” class. It infers the properties of normal cases and from these properties can predict which examples are unlike the normal examples. This is useful for anomaly detection because the scarcity of training examples is what defines anomalies: that is, typically there are very few examples of the network intrusion, fraud, or other anomalous behavior.
# 在一類 SVM 中，支援向量模型是在只有一個類別（即「正常」類別）的資料上進行訓練的。它推斷正常情況的屬性，並根據這些屬性可以預測哪些範例與正常範例不同。這對於異常偵測很有用，因為訓練範例的稀缺性就是定義異常的原因：也就是說，通常網路入侵、詐欺或其他異常行為的範例很少。
# > 在一類 SVM 中，支援向量模型是在只有一個類別（即「正常」類別）的資料上進行訓練的。它推斷正常情況的屬性，並根據這些屬性可以預測哪些範例與正常範例不同。這對於異常偵測很有用，因為訓練範例的稀缺性就是定義異常的原因：也就是說，通常網路入侵、詐欺或其他異常行為的範例很少。

# %%
model = OneClassSVM(kernel='rbf', degree=3, gamma=0.1, nu=0.005, max_iter=-1)

model.fit(x_train_us, np.ravel(y_train_us))
y_pred = model.fit_predict(x_test_us)

# %% [markdown]
# ## Confusion Matrix for One Class SVM; 一類 SVM 的混淆矩陣

# %%
# evaluating the model 評估模型
# printing the confusion matrix 列印混淆矩陣
cm = confusion_matrix(y_test_us, y_pred)
sns.heatmap(cm ,annot = True, cmap = 'winter')
# Out:
# <Axes: >

# %%
#print("Accuracy: ", model.score(x_test,y_test)*100) print("準確率：", model.score(x_test,y_test)*100)

# %% [markdown]
# ## OneClassSVM - (Oversampled); OneClassSVM -（過採樣）

# %%
model = OneClassSVM(kernel='rbf', degree=3, gamma=0.1, nu=0.005, max_iter=-1)

model.fit(x_train_os, np.ravel(y_train_os))
y_pred = model.fit_predict(x_test_os)

# %% [markdown]
# ## Confusion matrix for OneClassSVM - (Oversampled); OneClassSVM 的混淆矩陣 - （過採樣）

# %%
# evaluating the model 評估模型
# printing the confusion matrix 列印混淆矩陣
cm = confusion_matrix(y_test_os, y_pred)
sns.heatmap(cm ,annot = True, cmap = 'winter')
# Out:
# <Axes: >

# %% [markdown]
# ## Using PCA for demensionality reduction; 使用 PCA 進行降維

# %%
#Scaling the data before applying PCA 應用 PCA 之前縮放數據
from scipy.stats import zscore
data_new=data.iloc[:,:306].apply(zscore)
data_new.head()
# Out:
#           0         1         2         3         4         8         9  \
# 0  0.139998  0.429208  0.032735  0.059342 -0.049911  0.436850  1.128343
# 1  0.464020 -0.105874  0.236852  0.173847 -0.059375  0.393723  0.022511
# 2 -0.351256  0.407233  0.026413  0.684661 -0.047236 -0.192349  0.327111
# 3 -0.070903 -0.025985  0.086766 -1.033387 -0.050620  0.300837 -0.765478
# 4  0.146544  0.098340  0.250931 -0.125070 -0.046823  0.465600 -0.149655
#
#          10        11  13  ...       565       570       571       572  \
# 0 -0.381523 -0.481360 NaN  ... -1.305710  0.190142  0.034410 -0.226018
# 1 -1.608226 -0.011526 NaN  ... -1.305710  0.256816  1.205944 -0.261137
# 2  0.124224 -0.044305 NaN  ...  5.447531  0.257279 -0.263745 -0.199823
# 3 -0.370762 -0.006063 NaN  ...  0.464315  0.002548 -0.278290 -0.221613
# 4 -0.790424 -0.169959 NaN  ... -1.305710  0.085279 -0.270290 -0.227409
#
#         578       582        583       586       587       589
# ...

# %%
data_new.isnull().any().any()
# Out:
# np.True_

# %%
data_new = data_new.replace(np.nan, 0)

# %%
data_new.isnull().any().any()
# Out:
# np.False_

# %%
# separating the dependent and independent data 分離相關數據和獨立數據

x = data_new.iloc[:,:306]
y = data["Pass/Fail"]

# getting the shapes of new data sets x and y Error 500 (Server Error)!!1500.That’s an error.There was an error. Please try again later.That’s all we know.
# 取得新資料集 x 和 y 的形狀錯誤 500（伺服器錯誤）！ ！ 1500。這是一個錯誤。出現錯誤。請稍後重試。我們只知道這些。
# 獲取新資料集的形狀x和y錯誤500 （伺服器錯誤） ！ ！ 1500。這是一個錯誤。有一個錯誤。請稍後再試。這是我們所知道的。
print("shape of x:", x.shape)
print("shape of y:", y.shape)
# Out:
# shape of x: (1567, 306)
# shape of y: (1567,)

# %%
# PCA 主成分分析
# Step 1 - Create covariance matrix 步驟 1 - 建立協方差矩陣

cov_matrix = np.cov(x.T)
print('Covariance Matrix \n%s', cov_matrix)
# Out:
# Covariance Matrix
# %s [[ 1.00063857 -0.04781282  0.00759455 ...  0.04477373  0.00523674
#    0.02150242]
#  [-0.04781282  1.00063857 -0.03046719 ... -0.00922529  0.03950455
#    0.04449214]
#  [ 0.00759455 -0.03046719  1.00063857 ...  0.01574304 -0.00709495
#   -0.03045388]
#  ...
#  [ 0.04477373 -0.00922529  0.01574304 ...  1.00063857  0.16974222
#   -0.48505059]
#  [ 0.00523674  0.03950455 -0.00709495 ...  0.16974222  1.00063857
#    0.39175294]
#  [ 0.02150242  0.04449214 -0.03045388 ... -0.48505059  0.39175294
#    1.00063857]]

# %%
# Step 2- Get eigen values and eigen vector 步驟2-取得特徵值和特徵向量
eig_vals, eig_vecs = np.linalg.eig(cov_matrix)
print('Eigen Vectors \n%s', eig_vecs)
print('\n Eigen Values \n%s', eig_vals)
# Out:
# Eigen Vectors
# %s [[-0.0253695  -0.008654    0.00303277 ...  0.          0.
#    0.        ]
#  [-0.0025788   0.00538507  0.03440905 ...  0.          0.
#    0.        ]
#  [ 0.02753407  0.00681287  0.01400105 ...  0.          0.
#    0.        ]
#  ...
#  [-0.048536   -0.05395333  0.04823939 ...  0.          0.
#    0.        ]
#  [ 0.01242541  0.02265625 -0.00838096 ...  0.          0.
#    0.        ]
#  [ 0.0256921   0.06086426 -0.04287574 ...  0.          0.
#    0.        ]]
#
#  Eigen Values
# %s [7.98315826 4.02662836 3.83340365 3.77872193 3.24842052 3.04338189
#  2.81987221 2.70184859 2.63844411 2.49433697 2.39544185 2.33496444
#  2.2688959  2.21004546 2.18253643 2.11987395 2.06331064 2.01071359
#  2.02389709 1.99863763 1.98267329 1.95915582 1.92095551 1.8898469
#  1.85708597 1.83222209 1.79047783 1.77162466 1.74830769 1.69223045
#  1.6721054  1.64351825 1.63509768 1.61120278 1.58746461 1.59353955
#  1.54878319 1.54342972 1.51376615 1.4987913  1.39927034 1.42330375
# ...

# %%
tot = sum(eig_vals)
var_exp = [( i /tot ) * 100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
print("Cumulative Variance Explained", cum_var_exp)
# Out:
# Cumulative Variance Explained [  4.11240397   6.18666104   8.16138131  10.10793312  11.78130812
#   13.34906055  14.80167533  16.19349202  17.55264684  18.83756703
#   20.07154289  21.27436472  22.44315234  23.58162404  24.70592487
#   25.79794607  26.86082953  27.90340969  28.93919857  29.96876671
#   30.99011105  31.99934072  32.98889207  33.96241829  34.91906821
#   35.86290988  36.78524762  37.69787343  38.59848786  39.47021494
#   40.3315749   41.17820862  42.02050462  42.85049151  43.67137946
#   44.48913799  45.28697037  46.08204499  46.86183886  47.63391867
#   48.39069629  49.14236158  49.88946889  50.62266242  51.3434755
#   52.05100785  52.75441472  53.44575446  54.13150394  54.80518611
#   55.47224219  56.13386282  56.78335336  57.43035818  58.06247379
#   58.68657041  59.30627663  59.91402001  60.51888826  61.11881541
#   61.71313647  62.30277087  62.88054936  63.45680398  64.02642122
#   64.58794689  65.14526769  65.69372362  66.23286709  66.7660594
# ...

# %%
plt.plot(var_exp)

# %%
# Ploting  繪圖
plt.figure(figsize=(10 , 5))
plt.bar(range(1, eig_vals.size + 1), var_exp, alpha = 0.5, align = 'center', label = 'Individual explained variance')
plt.step(range(1, eig_vals.size + 1), cum_var_exp, where='mid', label = 'Cumulative explained variance')
plt.ylabel('Explained Variance Ratio')
plt.xlabel('Principal Components')
plt.legend(loc = 'best')
plt.tight_layout()
plt.show()

# %%
len(cum_var_exp)
# Out:
# 306

# %%
# Using scikit learn PCA here. It does all the above steps and maps data to PCA dimensions in one shot
# 在這裡使用 scikit 學習 PCA。它一次完成上述所有步驟並將資料映射到 PCA 維度
# 使用scikit在此處學習PCA。它完成上述所有步驟，並將數據一次性映射到PCA維度
# 在這裡使用 scikit 學習 PCA。它一次完成上述所有步驟並將資料映射到 PCA 維度
from sklearn.decomposition import PCA

# NOTE - we are generating only 130 PCA dimensions (dimensionality reduction from 306 to 130)
# 注意 - 我們僅產生 130 個 PCA 維度（維度從 306 減少到 130）
# 注意-我們只產生130個PCA維度（維度從306減少到130 ）
# 注意 - 我們僅產生 130 個 PCA 維度（維度從 306 減少到 130）
# For 130 components we are getting approximately 90% of the variance
# 對於 130 個組件，我們得到大約 90% 的方差
pca = PCA(n_components=130)
data_reduced = pca.fit_transform(x)
data_reduced.transpose()
# Out:
# array([[-3.26185845e+00, -1.81271314e+00, -2.21584437e+00, ...,
#          5.38607745e+00,  4.57167569e+00,  5.28922316e+00],
#        [-8.02821293e-02, -8.46091143e-01, -2.62162600e-01, ...,
#         -3.48973657e+01, -4.06171018e+00, -3.53855887e+01],
#        [-2.10907724e-01, -9.59879424e-01, -1.19322746e+00, ...,
#          3.05865768e+00,  2.00041711e+00,  5.14320522e+00],
#        ...,
#        [-2.84267307e-01, -8.00691415e-01, -1.22154741e+00, ...,
#          1.35718450e+00,  1.75463525e+00,  8.42350818e-02],
#        [ 5.28495221e-02,  5.46376236e-01, -2.42150838e-01, ...,
#          1.48828377e-02, -8.49736489e-01,  7.44841190e-01],
#        [ 1.80521580e+00, -6.46425548e-01, -4.49960821e-01, ...,
#          7.71869645e-01, -1.28771142e+00,  6.62732235e-01]],
#       shape=(130, 1567))

# %%
pca.components_
# Out:
# array([[ 0.02536948,  0.00257881, -0.02753406, ...,  0.04853603,
#         -0.01242537, -0.02569216],
#        [ 0.00865383, -0.00538373, -0.0068146 , ...,  0.05395422,
#         -0.02265523, -0.06086506],
#        [-0.0030322 , -0.03440723, -0.01400591, ..., -0.04823829,
#          0.00838202,  0.04287302],
#        ...,
#        [-0.00313593,  0.04254372,  0.02836092, ...,  0.0952714 ,
#          0.10054379, -0.08184499],
#        [-0.10877965, -0.08228944,  0.05877492, ..., -0.00536059,
#          0.00889672,  0.04566357],
#        [ 0.03309977,  0.04054238,  0.03477333, ..., -0.1374676 ,
#         -0.04124039,  0.01905069]], shape=(130, 306))

# %%
df_comp = pd.DataFrame(pca.components_,columns=list(x))
df_comp.head()
# Out:
#           0         1         2         3         4         8         9  \
# 0  0.025369  0.002579 -0.027534  0.066608  0.024699 -0.077981  0.031003
# 1  0.008654 -0.005384 -0.006815 -0.043183 -0.000091  0.217424 -0.002423
# 2 -0.003032 -0.034407 -0.014006 -0.003738 -0.003484 -0.062300 -0.011084
# 3 -0.011017  0.019494  0.031018  0.008147  0.037435  0.027084 -0.034177
# 4 -0.001612 -0.024109 -0.050001 -0.037776 -0.031000  0.003800 -0.003773
#
#          10        11            13  ...       565       570       571  \
# 0 -0.017991  0.011328  1.654361e-24  ...  0.103563  0.017317 -0.095065
# 1 -0.042956  0.307620 -1.734723e-18  ... -0.013688  0.015339 -0.029587
# 2 -0.037444 -0.033600 -0.000000e+00  ... -0.032970 -0.007396 -0.011179
# 3  0.030427  0.011604 -5.551115e-17  ...  0.042448 -0.031512 -0.018136
# 4 -0.000669 -0.092512 -0.000000e+00  ... -0.051730 -0.022407  0.033648
#
#         572       578       582       583       586       587       589
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_comp,cmap='plasma',)
# Out:
# <Axes: >

# %%
data_reduced.shape
# Out:
# (1567, 130)

# %%
df_red2 = pd.DataFrame(data_reduced)
df_red2.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -3.261858 -0.080282 -0.210908 -0.872298 -0.619051  0.753747  0.013345
# 1 -1.812713 -0.846091 -0.959879 -0.070686  0.165206  0.658082  1.083970
# 2 -2.215844 -0.262163 -1.193227  2.265561 -1.239834 -0.951372 -2.024345
# 3 -3.617115 -0.816759 -0.816859  2.152508 -2.613054 -1.409056 -1.174086
# 4 -2.765985 -0.133777  1.444615  2.270495 -1.498061 -0.623667  2.928906
#
#         7         8         9    ...       120       121       122       123  \
# 0 -0.573104 -3.189398  1.888983  ...  0.399592  0.490223 -0.055188  0.465547
# 1  0.301761 -2.560290  1.301356  ... -0.372302 -0.314661 -0.848856  1.297065
# 2  0.906076 -1.154411 -1.810654  ... -0.287396 -0.181101 -1.166039  0.007024
# 3  0.842907 -0.293670 -2.762742  ... -0.812583  1.807304  5.784848  0.687724
# 4 -1.896376  2.506721  1.483766  ... -0.161951  0.788843  0.388461 -0.578714
#
#         124       125       126       127       128       129
# ...

# %%
df_red3 = df_red2.copy()
df_red4 = df_red3
df_red4["Pass/Fail"] = data["Pass/Fail"]

# %%
df_red4.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -3.261858 -0.080282 -0.210908 -0.872298 -0.619051  0.753747  0.013345
# 1 -1.812713 -0.846091 -0.959879 -0.070686  0.165206  0.658082  1.083970
# 2 -2.215844 -0.262163 -1.193227  2.265561 -1.239834 -0.951372 -2.024345
# 3 -3.617115 -0.816759 -0.816859  2.152508 -2.613054 -1.409056 -1.174086
# 4 -2.765985 -0.133777  1.444615  2.270495 -1.498061 -0.623667  2.928906
#
#           7         8         9  ...       121       122       123       124  \
# 0 -0.573104 -3.189398  1.888983  ...  0.490223 -0.055188  0.465547  1.197155
# 1  0.301761 -2.560290  1.301356  ... -0.314661 -0.848856  1.297065 -0.231884
# 2  0.906076 -1.154411 -1.810654  ... -0.181101 -1.166039  0.007024  0.144730
# 3  0.842907 -0.293670 -2.762742  ...  1.807304  5.784848  0.687724 -1.444520
# 4 -1.896376  2.506721  1.483766  ...  0.788843  0.388461 -0.578714 -0.145462
#
#         125       126       127       128       129  Pass/Fail
# ...

# %%
df_red4.shape
# Out:
# (1567, 131)

# %%
#Causing system crash and taking too much time, so commented out
# 導致系統崩潰，耗時過多，所以註解掉
#sns.pairplot(df_red4,diag_kind='kde') sns.pairplot(df_red4,diag_kind='kde')
# sns.pairplot (df_red4, diag_kind = 'kde') sns.pairplot (df_red4, diag_kind = 'kde')
# sns.pairplot (df_red4, diag_kind = 'kde') sns.pairplot (df_red4, diag_kind = 'kde')
# sns.pairplot (df_red4, diag_kind = 'kde') sns.pairplot (df_red4, diag_kind = 'kde')

# %%
#Sample boxplot shows that there are outliers in the data, let us fix them
# 範例箱線圖顯示資料中存在異常值，讓我們修復它們
df_red4.boxplot(column = [df_red4.columns[0],
                          df_red4.columns[1],
                          df_red4.columns[2],
                          df_red4.columns[3], 
                          df_red4.columns[4],
                          df_red4.columns[5],
                         ]
                          , by = 'Pass/Fail', figsize=(20,20))
# Out:
# array([[<Axes: title={'center': '0'}, xlabel='Pass/Fail'>,
#         <Axes: title={'center': '1'}, xlabel='Pass/Fail'>],
#        [<Axes: title={'center': '2'}, xlabel='Pass/Fail'>,
#         <Axes: title={'center': '3'}, xlabel='Pass/Fail'>],
#        [<Axes: title={'center': '4'}, xlabel='Pass/Fail'>,
#         <Axes: title={'center': '5'}, xlabel='Pass/Fail'>]], dtype=object)

# %%
#Create a copy of the dataset for maintain data after outlier removal
# 建立資料集的副本，以便在移除異常值後維護數據
#Here after identifying outliers we replace with median 在識別出異常值後，我們用中位數替換
pd_data = df_red4.copy()
#pd_data.head() pd_data.head() pd_data.head () pd_data.head ()
# pd_data.head () pd_data.head () pd_data.head () pd_data.head ()
# 中文翻譯待補
# pd_data.head () pd_data.head () pd_data.head () pd_data.head ()
# 中文翻譯待補

#pd_data2 = pd_data.drop(columns=['name'],axis=1) pd_data2 = pd_data.drop(列=['名稱'],軸=1)
#pd_data2 = pd_data2.apply(replace,axis=1) pd_data2 = pd_data2.apply(替換，軸=1)
from scipy import stats

#Define a function to remove outliers on max side 定義一個函數來刪除最大一側的異常值
def outlier_removal_max(var):
    var = np.where(var > var.quantile(0.75)+ stats.iqr(var),var.quantile(0.50),var)
    return var

#Define a function to remove outliers on min side 定義一個函數來刪除最小側的異常值
def outlier_removal_min(var):
    var = np.where(var < var.quantile(0.25) - stats.iqr(var),var.quantile(0.50),var)
    return var

#Loop over the columns and remove the outliers on min and max side
# 循環列並刪除最小和最大一側的異常值
for column in pd_data:
    pd_data[column] = outlier_removal_max(pd_data[column])
    pd_data[column] = outlier_removal_min(pd_data[column])

# %%
#Sample boxplot shows that outliers are fixed, but we are loosing observations belonging to failure 
# 範例箱線圖顯示異常值是固定的，但我們正在失去屬於失敗的觀察結果
#class (Pass/Fail = 1) So we should not remove outliers here  類別（通過/失敗= 1）所以我們不應該在這裡刪除異常值
pd_data.boxplot( column =[df_red4.columns[0],
                          df_red4.columns[1],
                          df_red4.columns[2],
                          df_red4.columns[3], 
                          df_red4.columns[4],
                          df_red4.columns[5],
                         ],by = 'Pass/Fail', figsize=(20,20))
# Out:
# array([[<Axes: title={'center': '0'}, xlabel='Pass/Fail'>,
#         <Axes: title={'center': '1'}, xlabel='Pass/Fail'>],
#        [<Axes: title={'center': '2'}, xlabel='Pass/Fail'>,
#         <Axes: title={'center': '3'}, xlabel='Pass/Fail'>],
#        [<Axes: title={'center': '4'}, xlabel='Pass/Fail'>,
#         <Axes: title={'center': '5'}, xlabel='Pass/Fail'>]], dtype=object)

# %%
# separating the dependent and independent data 分離相關數據和獨立數據

x = df_red4.iloc[:, df_red4.columns != 'Pass/Fail'] 
y = df_red4.iloc[:, df_red4.columns == 'Pass/Fail']

# getting the shapes of new data sets x and y Error 500 (Server Error)!!1500.That’s an error.There was an error. Please try again later.That’s all we know.
# 取得新資料集 x 和 y 的形狀錯誤 500（伺服器錯誤）！ ！ 1500。這是一個錯誤。出現錯誤。請稍後重試。我們只知道這些。
# 獲取新資料集的形狀x和y錯誤500 （伺服器錯誤） ！ ！ 1500。這是一個錯誤。有一個錯誤。請稍後再試。這是我們所知道的。
print("shape of x:", x.shape)
print("shape of y:", y.shape)
# Out:
# shape of x: (1567, 130)
# shape of y: (1567, 1)

# %%
# Under Sampling - Check how many failure observations are there
# 採樣下 - 檢查有多少個故障觀察結果
# We have 104 such observations 我們有 104 個這樣的觀察結果

failed_tests = np.array(df_red4[df_red4['Pass/Fail'] == 1].index)
no_failed_tests = len(failed_tests)

print(no_failed_tests)
# Out:
# 104

# %%
# Check how many pass observations are there 檢查有多少次通過觀察
# We have 1,463 such observations 我們有 1,463 個這樣的觀察結果

normal_indices = df_red4[df_red4['Pass/Fail'] == -1]
no_normal_indices = len(normal_indices)

print(no_normal_indices)
# Out:
# 1463

# %%
# Get 104 random observations from the pass class as well 也從合格類別中獲得 104 個隨機觀察結果

random_normal_indices = np.random.choice(no_normal_indices, size = no_failed_tests, replace = True)
random_normal_indices = np.array(random_normal_indices)

print(len(random_normal_indices))
# Out:
# 104

# %%
#Getting a 50-50 representation from both pass and fail classes
# 透過類和失敗類均獲得 50-50 的表現
under_sample = np.concatenate([failed_tests, random_normal_indices])
print(len(under_sample))
# Out:
# 208

# %%
# creating the undersample data 創建欠採樣數據

undersample_data = df_red4.iloc[under_sample, :]

# splitting the undersample dataset into x and y sets 將欠採樣資料集拆分為 x 和 y 集

x = undersample_data.iloc[:, undersample_data.columns != 'Pass/Fail'] 
y = undersample_data.iloc[:, undersample_data.columns == 'Pass/Fail']

print(x.shape)
print(y.shape)
# Out:
# (208, 130)
# (208, 1)

# %%
from sklearn.model_selection import train_test_split

x_train_us, x_test_us, y_train_us, y_test_us = train_test_split(x, y, test_size = 0.3, random_state = 1)

print(x_train_us.shape)
print(y_train_us.shape)
print(x_test_us.shape)
print(y_test_us.shape)
# Out:
# (145, 130)
# (145, 1)
# (63, 130)
# (63, 1)

# %%
# standardization - completed before PCA itself 標準化 - 在 PCA 本身之前完成
#sc = StandardScaler() sc = 標準縮放器()
#x_train_us = sc.fit_transform(x_train_us) x_train_us = sc.fit_transform(x_train_us)
# x_train_us = sc.fit_transform (x_train_us) x_train_us = sc.fit_transform (x_train_us)
# x_train_us = sc.fit_transform (x_train_us) x_train_us = sc.fit_transform (x_train_us)
# x_train_us = sc.fit_transform (x_train_us) x_train_us = sc.fit_transform (x_train_us)
#x_test_us = sc.transform(x_test_us) x_test_us = sc.transform(x_test_us)
# x_test_us = sc.transform (x_test_us) x_test_us = sc.transform (x_test_us)
# x_test_us = sc.transform (x_test_us) x_test_us = sc.transform (x_test_us)
# x_test_us = sc.transform (x_test_us) x_test_us = sc.transform (x_test_us)

# %% [markdown]
# ## XGBoost - PCA (undersampled); XGBoost - PCA（欠採樣）

# %%
model = XGBClassifier(random_state=1)

model.fit(x_train_us, (np.ravel(y_train_us) == 1).astype(int))

y_pred = model.predict(x_test_us)

cm = confusion_matrix(y_test_us, y_pred)

# %% [markdown]
# ## Confusion matrix for XG Boost - PCA - (Undersampled); XG Boost 的混淆矩陣 - PCA -（欠採樣）

# %%
plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
sns.heatmap(cm, annot = True, annot_kws = {"size": 15})
# Out:
# <Axes: >

# %%
print("Accuracy: ", model.score(x_test_us,y_test_us)*100)
# Out:
# Accuracy:  30.158730158730158

# %% [markdown]
# ## XG Boost - PCA - Grid Search - Undersampled; XG Boost - PCA - 網格搜尋 - 欠採樣

# %%
# Applying Grid Search CV to find the best model with the best parameters
# 應用 Grid Search CV 尋找具有最佳參數的最佳模型
# 應用網格搜尋CV以尋找具有最佳參數的最佳模型
# 應用 Grid Search CV 尋找具有最佳參數的最佳模型

parameters = [{'max_depth' : [1, 2, 3, 4, 5, 6],
             'random_state' : [1]}]

grid_search = GridSearchCV(estimator = model, param_grid = parameters, scoring = 'accuracy', cv = 5, n_jobs = -1)

grid_search = grid_search.fit(x_train_us, (np.ravel(y_train_us) == 1).astype(int))
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_

print("Best Accuracy: ", best_accuracy*100)
print("Best Parameter: ", best_parameters)
# Out:
# Best Accuracy:  64.13793103448275
# Best Parameter:  {'max_depth': 6, 'random_state': 1}

# %%
y_train_us_xgb = (np.ravel(y_train_us) == 1).astype(int)
weights = float((y_train_us_xgb == 0).sum()) / max(1.0, float((y_train_us_xgb == 1).sum()))
model = XGBClassifier(max_depth = 1, scale_pos_weight = weights, n_jobs = 4, random_state=1)

model.fit(x_train_us, (np.ravel(y_train_us) == 1).astype(int))

y_pred = model.predict(x_test_us)

print("Accuracy: ", model.score(x_test_us,y_test_us)*100)
# Out:
# Accuracy:  30.158730158730158

# %% [markdown]
# ## Confusion matrix of XG Boost - Grid Search - PCA - Undersampled
# XG Boost 的混淆矩陣 - 網格搜尋 - PCA - 欠採樣
# ## XG Boost 的混淆矩陣 - 網格搜尋 - PCA - 欠採樣

# %%
cm = confusion_matrix(y_test_us, y_pred)

plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
sns.heatmap(cm, annot = True, annot_kws = {"size": 15})
# Out:
# <Axes: >

# %% [markdown]
# ## Random Forest - PCA - Undersampled 隨機森林 - PCA - 欠採樣

# %%
model = RandomForestClassifier(n_estimators=100, random_state=1,verbose=0 )
model.fit(x_train_us, (np.ravel(y_train_us) == 1).astype(int))
#scores_prediction = model.decision_function(x_train) Scores_prediction = model.decision_function(x_train)
# 分數_預測 = model.decision_function(x_train) 分數_預測 = model.decision_function(x_train)
# scores_prediction = model.decision_function (x_train) Scores_prediction = model.decision_function (x_train)
# 分數_預測 = model.decision_function (x_train) 分數_預測 = model.decision_function (x_train)
y_pred = model.predict(x_test_us)

# evaluating the model 評估模型

# printing the confusion matrix 列印混淆矩陣
cm = confusion_matrix(y_test_us, y_pred)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %%
print("Accuracy: ", model.score(x_test_us,y_test_us)*100)
# Out:
# Accuracy:  31.746031746031743

# %% [markdown]
# ## Logistic Regression - PCA - Undersampled Logistic 回歸 - PCA - 欠採樣

# %%
lr = LogisticRegression(random_state=1)
lr.fit(x_train_us, np.ravel(y_train_us)) 
y_pred = lr.predict(x_test_us)
cm = confusion_matrix(y_test_us, y_pred)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %%
print("Accuracy: ", lr.score(x_test_us,y_test_us)*100)
# Out:
# Accuracy:  61.904761904761905

# %% [markdown]
# ## Lasso - PCA - Undersampled ## Lasso - PCA - 欠採樣

# %%
lasso = Lasso(alpha=0.1,random_state=1)
lasso.fit(x_train_us, np.ravel(y_train_us))
#print ("Lasso model:", (lasso.coef_)) print ("套索模型：", (lasso.coef_))

y_pred = lasso.predict(x_test_us)

#Convert the sign of the predicted values as the classifier 將預測值的符號轉換為分類器
y_pred2 = np.sign(y_pred)

# %%
actual_cost = list(y_test_us)
actual_cost = np.asarray(actual_cost)
y_pred_lass = lasso.predict(x_test_us)

# %%
print("Accuracy: ", lasso.score(x_test_us, y_test_us)*100)
# Out:
# Accuracy:  11.617041641921922

# %% [markdown]
# ## Confusion Matrix for Lasso - PCA - Undersampled Lasso 的混淆矩陣 - PCA - 欠取樣

# %%
cm = confusion_matrix(y_test_us, y_pred2)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %% [markdown]
# ## Elliptic Envelop technique 橢圓包絡技術

# %%
# defining outlier fraction for Elliptic Envelop, Isolation Forest and Local Outlier Factor
# 定義橢圓包絡、隔離森林和局部離群因子的離群值分數

Fraud = data[data['Pass/Fail']==1]
Valid = data[data['Pass/Fail']==-1]

outlier_fraction = len(Fraud)/float(len(Valid))
print("Outlier Fraction :", outlier_fraction)
# Out:
# Outlier Fraction : 0.0710868079289132

# %%
from sklearn.covariance import EllipticEnvelope
import warnings

model = EllipticEnvelope(contamination=outlier_fraction, random_state=1)
with warnings.catch_warnings():
    warnings.filterwarnings(
        "ignore",
        message="The covariance matrix associated to your dataset is not full rank",
        category=UserWarning,
    )
    model.fit(x_train)
#scores_prediction = model.decision_function(x_train) Scores_prediction = model.decision_function(x_train)
# 分數_預測 = model.decision_function(x_train) 分數_預測 = model.decision_function(x_train)
# scores_prediction = model.decision_function (x_train) Scores_prediction = model.decision_function (x_train)
# 分數_預測 = model.decision_function (x_train) 分數_預測 = model.decision_function (x_train)
y_pred = model.predict(x_test)

# %%
# printing the confusion matrix 列印混淆矩陣
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %% [markdown]
# ## Isolation Forest technique 隔離森林技術

# %%
from sklearn.ensemble import IsolationForest

model = IsolationForest(n_estimators=100, max_samples=len(x_train), 
                                       contamination=outlier_fraction, random_state=1, verbose=0)
model.fit(x_train)
scores_prediction = model.decision_function(x_train)
y_pred = model.predict(x_test)

# %%
# printing the confusion matrix 列印混淆矩陣
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %% [markdown]
# ## Local Outlier Factor Technique 局部離群因子技術

# %%
from sklearn.neighbors import LocalOutlierFactor

model = LocalOutlierFactor(n_neighbors=20, algorithm='auto', leaf_size=30, metric='minkowski', p=2, 
                           metric_params=None, contamination=outlier_fraction)

model.fit(x_train)
y_pred = model.fit_predict(x_test)

# %%
# printing the confusion matrix 列印混淆矩陣
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %% [markdown]
# ## Comparison of All Algorithms' Recall Rate 各演算法召回率對比

# %%
Recall = np.array([84.4, 87.9, 81.3,9.4,0,0,0])
label = np.array(['Isolation Forest', 'Local Outlier Factor', 'Elliptic Envelop',
                  'Logistic','XGBoost','Random Forest','Lasso'])
indices = np.argsort(Recall)
color = plt.cm.rainbow(np.linspace(0, 1, 9))

plt.rcParams['figure.figsize'] = (18, 7)
plt.bar(range(len(indices)), Recall[indices], color = color)
plt.xticks(range(len(indices)), label[indices])
plt.title('Recall Accuracy - Normal Data', fontsize = 30)
plt.grid()
plt.tight_layout()
plt.show()

# %%
Recall = np.array([74.3,77.1,71.4,77.1,71.4,17.1])
label = np.array(['XG Boost','XG Boost - Grid Search','Random Forest','Logistic','Lasso','OneClass SVM'])
indices = np.argsort(Recall)
color = plt.cm.rainbow(np.linspace(0, 1, 9))

plt.rcParams['figure.figsize'] = (18, 7)
plt.bar(range(len(indices)), Recall[indices], color = color)
plt.xticks(range(len(indices)), label[indices])
plt.title('Recall Accuracy - Undersampled Data', fontsize = 30)
plt.grid()
plt.tight_layout()
plt.show()

# %%
Recall = np.array([74.3,77.1,71.4,77.1,71.4,17.1])
label = np.array(['XG Boost','XG Boost - Grid Search','Random Forest','Logistic','Lasso','OneClass SVM'])
indices = np.argsort(Recall)
color = plt.cm.rainbow(np.linspace(0, 1, 9))

plt.rcParams['figure.figsize'] = (18, 7)
plt.bar(range(len(indices)), Recall[indices], color = color)
plt.xticks(range(len(indices)), label[indices])
plt.title('Recall Accuracy - Oversampled Data', fontsize = 30)
plt.grid()
plt.tight_layout()
plt.show()

# %%
Recall = np.array([54.5,63.6,48.5,69.7,51.5])
label = np.array(['XG Boost','XG Boost - Grid Search','Random Forest','Logistic','Lasso'])
indices = np.argsort(Recall)
color = plt.cm.rainbow(np.linspace(0, 1, 9))

plt.rcParams['figure.figsize'] = (18, 7)
plt.bar(range(len(indices)), Recall[indices], color = color)
plt.xticks(range(len(indices)), label[indices])
plt.title('Recall Accuracy - PCA Data', fontsize = 30)
plt.grid()
plt.tight_layout()
plt.show()

# %%
# plotting the feature importances 繪製特徵重要性

from numpy import loadtxt
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot
pyplot.rcParams.update({'font.size': 22})
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 10), dpi=120, facecolor='w', edgecolor='k')
# fit model no training data 擬合模型無訓練數據
model = XGBClassifier()
model.fit(x_train_us, (np.ravel(y_train_us) == 1).astype(int))
# plot feature importance 情節特徵重要性
plot_importance(model, max_num_features=30, importance_type='gain')
pyplot.tight_layout()
pyplot.show()

# %%
featureImp = []
for feat, importance in zip(data.columns, model.feature_importances_):  
    temp = [feat, importance*100]
    featureImp.append(temp)

fT_df = pd.DataFrame(featureImp, columns = ['Feature', 'Importance'])
print (fT_df.sort_values('Importance', ascending = False))
# Out:
#     Feature  Importance
# 76      118    4.850487
# 102     157    3.793787
# 12       16    3.784516
# 9        13    3.242544
# 96      149    3.185821
# ..      ...         ...
# 49       83    0.000000
# 71      113    0.000000
# 13       19    0.000000
# 103     158    0.000000
# 47       81    0.000000
#
# [130 rows x 2 columns]

# %% [markdown]
# ## We have tried multiple models Logistic Regression, Random Forest, XG Boost (with and without Grid Search),OneClassSVM, Elliptic Envelop, Isolation Forest and Local Outlier Factor for the imbalanced classes
# 我們針對不平衡類別嘗試了多種模型 Logistic 迴歸、隨機森林、XG Boost（有或沒有網格搜尋）、OneClassSVM、橢圓包絡、隔離森林和局部離群因子
# ## 我們針對不平衡類別嘗試了多種模型 Logistic 迴歸、隨機森林、XG Boost（有或沒有網格搜尋）、OneClassSVM、Elliptic Envelop、Isolation Forest 和 Local Outlier Factor
# ## Across methods OneClassSVM performed the worst while Local Outlier Factor performed the best in terms of recall accuracy
# 在各種方法中，OneClassSVM 在召回率方面表現最差，而局部離群因子則表現最佳
# ## 在各種方法中，OneClassSVM 在召回率方面表現最差，而 Local Outlier Factor 表現最好
# ## We saw that for imbalanced classes accuracy and recall are invertially proportional to each other. Better recall models have lower accuracy and vice versa.
# 我們看到，對於不平衡的類別，準確率和召回率彼此成反比。更好的召回模型的準確性較低，反之亦然。
# ## We have tried two sampling techniques -first one using SMOTE (oversampling) and second one
# 我們嘗試了兩種採樣技術 - 第一種使用 SMOTE（過採樣），第二種使用 SMOTE（過採樣）
# ## 我們嘗試了兩種採樣技術 - 第一種使用 SMOTE（過採樣），第二種使用 SMOTE（過採樣）
# ## using random based method (undersampling), Oversampling gave better results than undersampling in
# 使用基於隨機的方法（欠採樣），過採樣比欠採樣給出了更好的結果
# ## terms of accuracy. Recall score was similar for both undersampling and oversampling.
# 準確性方面。欠採樣和過採樣的召回分數相似。
# ## We did Z score scaling on both the datasets and took PCA with n_components as 130 (90% variance coverage). However PCA did not improve either accuracy or recall probably as we were loosing information due to dropping dimensions.
# 我們對兩個資料集進行了 Z 分數縮放，並將 n_components 的 PCA 設為 130（90% 變異數覆蓋）。然而，PCA 並沒有提高準確度或召回率，可能是因為我們因為維度下降而失去了資訊。
# ## 我們對兩個資料集進行了 Z 分數縮放，並將 n_components 的 PCA 設為 130（90% 變異數覆蓋）。然而，PCA 並沒有提高準確度或召回率，可能是因為我們因為維度下降而失去了資訊。
# ## We tried K-fold cross validation within XG Boost itself with bext value as 2 for all the models
# 我們在 XG Boost 本身中嘗試了 K 折交叉驗證，所有模型的 bext 值為 2
# ## 我們在 XG Boost 本身中嘗試了 K 折交叉驗證，所有模型的 bext 值為 2
# ## Using feature importance, we found that 72, 74 and 45 are the top three important
# 使用特徵重要性，我們發現 72、74 和 45 是最重要的前三個
# ## features. The best recall value at 88% was for Local Outlier Factor algorithm, the best part was no sampling was required as the algorithm took care of sampling as well as outliers.
# 特徵。局部異常值因子演算法的最佳召回率為 88%，最好的部分是不需要取樣，因為演算法會處理取樣和異常值。
# ## classifier on the failure observations ## 故障觀察的分類器
